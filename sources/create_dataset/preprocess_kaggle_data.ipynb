# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', 800)

# %%
df = pd.read_csv(r"C:\Users\eupho\OneDrive\Documents\perso\projets\classification_texte_articles\data\output\sceptic_theist\best_model\false_predictions.csv")
df
# Out:
#        id    truth     pred  \
# 0    4446  sceptic   theist
# 1    2662  sceptic   theist
# 2    3479   theist  sceptic
# 3    5558  sceptic   theist
# 4    5457  sceptic   theist
# ..    ...      ...      ...
# 197   461  sceptic   theist
# 198  3563   theist  sceptic
# 199  3299  sceptic   theist
# 200  1424  sceptic   theist
# 201   113  sceptic   theist
#
# ...

# %%
df = pd.read_csv(r"C:\Users\eupho\OneDrive\Documents\perso\projets\classification_texte_articles\data\input\merged_corpus\corpus_sceptic_theist.csv")
# df.query("category == 'sceptic'")
df = df[['id', 'message', 'message_preprocessed', 'length', 'category', 'category_bin']]
df.sort_values("length", inplace=True)
# df = df.query("length > 200")
# pd.set_option('display.max_colwidth', 800)
# pd.set_option('display.min_rows', 50)
# pd.set_option('display.max_rows', 50)
# pd.set_option('display.max_rows', None)
df
# Out:
#         id  \
# 8747  8747
# 8094  8094
# 4508  4508
# 3333  3333
# 4893  4893
# ...    ...
# 292    292
# 8356  8356
# 7135  7135
# 9778  9778
# 3179  3179
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               message  \
# ...

# %%
from IPython.display import display, HTML
display( HTML( df.to_html().replace("\\n","<br>") ) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>message</th>
#       <th>length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
df = pd.read_csv(r"C:\Users\eupho\OneDrive\Documents\perso\projets\backup\big_data\amazon_reviews_us_Electronics_v1_00.tsv.gz", 
        compression='gzip', sep='\t', on_bad_lines='skip')
df
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 0                US     41409413  R2MTG1GCZLR2DK  B00428R89M       112201306
# 1                US     49668221  R2HBOEM8LE9928  B000068O48       734576678
# 2                US     12338275  R1P4RW1R9FDPEE  B000GGKOG8       614448099
# 3                US     38487968  R1EBPM82ENI67M  B000NU4OTA        72265257
# 4                US     23732619  R372S58V6D11AT  B00JOQIO6S       308169188
# ...             ...          ...             ...         ...             ...
# 3091019          US     51216847   RZ3LLAKIZQ3RR  B00000JBAT       738692522
# 3091020          US     52953714  R1V8GVI67B7V0K  B00000JBAT       738692522
# 3091021          US     51764094  R3BDESK5VUNK8C  B00000J4FY       503765214
# 3091022          US     52011360  R1JJGM0JWVT7DV  B00000JHWN       662358399
# 3091023          US     51807224  R30PZG0PCGR2V0  0966185056       435880663
#
# ...

# %%
df = pd.read_csv(r"C:\Users\eupho\OneDrive\Documents\perso\projets\classification_texte_articles\data\input\other_raw_data\amazon_reviews_us_Electronics_v1_00.tsv.gz", 
        compression='gzip', sep='\t', on_bad_lines='skip')
df = df[["star_rating", "review_body"]]
df = df.query("star_rating == 1 or star_rating == 5")
df["category"] = np.select([df["star_rating"] == 5], ["positive"], default="negative")
df = df[['review_body', 'category']]
df.columns = ['message', 'category']
df = df[df["message"].notna()]
df.to_parquet(r"C:\Users\eupho\OneDrive\Documents\perso\projets\classification_texte_articles\data\input\raws_merged_corpus\corpus_amazon.parquet")
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  message  \
# ...
