# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', 800)

# %%
df = pd.read_csv(r"C:\Users\eupho\OneDrive\Documents\perso\projets\classification_texte_articles_version_objet\data\input\other_raw_data\amazon_reviews_us_Electronics_v1_00.tsv.gz", 
        compression='gzip', sep='\t', on_bad_lines='skip')
df = df[["star_rating", "review_body"]]
df = df.query("star_rating == 1 or star_rating == 5")
df["category"] = np.select([df["star_rating"] == 5], ["positive"], default="negative")
df = df[['review_body', 'category']]
df.columns = ['message', 'category']
df = df[df["message"].notna()]
df.to_parquet(r"C:\Users\eupho\OneDrive\Documents\perso\projets\classification_texte_articles_version_objet\data\input\raws_merged_corpus\corpus_amazon.parquet")
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  message  \
# ...
